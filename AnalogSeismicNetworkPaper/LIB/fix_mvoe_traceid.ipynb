# %%
#!/usr/bin/env python
import pandas as pd
import csv
import obspy
import matplotlib.pyplot as plt
import numpy as np
import trace_quality_control as qc
import os
import glob
import datetime as dt

def fix_nslc_montserrat(traceid):
# function tr = fix_nslc_montserrat(tr)
    # FIX NET, STA, LOC, CHAN CODES ###
    # fix the network, channel and location
    oldnet, oldsta, oldloc, oldcha = traceid.split('.')

    network = 'MV'
    chan = oldcha
    sta = oldsta
    loc = oldloc
    if chan=='PRS' or chan[0:2]=='AP':
        chan='BDF'
    else:
        if chan[0]=='A':
           if loc == 'J':
               bandcode = 'S'
           else:
               bandcode = chan[0]
        else:
            try:
                if chan[1]=='B':
                    bandcode = 'B'
                else:
                    bandcode = chan[0]
            except:
                bandcode = chan[0]
        instrumentcode = 'H'
        if len(chan)<3:
            orientationcode = oldloc
        else:
            orientationcode = chan[2]

        chan = bandcode + instrumentcode + orientationcode

    if chan[0]=='A':
        print(network, sta, chan, loc)
        sys.exit('bugger!')
    return network + "." + sta + "." + loc + "." + chan

# %%
days_df = pd.DataFrame()
list_of_csv_files = sorted(glob.glob('./MVOE_wavfiles*.csv'))
#print(list_of_csv_files)
all_trace_ids = list()
# get a list of all traceids
for csvfile in list_of_csv_files:
    #print(csvfile)
    df = pd.read_csv(csvfile)
    #print(df)
    df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
    # loop over every day in this month & make a summary row for each channel
    old_trace_ids = df.traceid.unique()
    all_trace_ids = list(set().union(all_trace_ids, old_trace_ids))
print('There are %d different traceids for the MVOE_ network' % len(all_trace_ids))
# Out:
# There are 252 different traceids for the MVOE_ network

# %%
for oldid in all_trace_ids:
    if oldid.find('MB')>-1:
        newid = fix_nslc_montserrat(oldid)
        print(oldid, '->', newid)
# Out:
# .MBGE.J.SBE -> MV.MBGE.J.BHE
# .MBGB.J.SBN -> MV.MBGB.J.BHN
# .MBBY..BHE -> MV.MBBY..BHE
# .MBBY..BHZ -> MV.MBBY..BHZ
# .MBLY..PR4 -> MV.MBLY..PH4
# MV.MBLY.--.BHZ -> MV.MBLY.--.BHZ
# .MBLG..BHE -> MV.MBLG..BHE
# .MBLY..PR6 -> MV.MBLY..PH6
# MV.MBLG.--.BHH -> MV.MBLG.--.BHH
# .MBGH.1.PR -> MV.MBGH.1.PH1
# .MBLY.1.PR -> MV.MBLY.1.PH1
# .MBLG..BHN -> MV.MBLG..BHN
# .MBGB.E.BH -> MV.MBGB.E.BHE
# .MBFR.E.BH -> MV.MBFR.E.BHE
# .MBWH.N.BH -> MV.MBWH.N.BHN
# .MBLY.R.P5 -> MV.MBLY.R.PHR
# MV.MBLYT.--.BHN -> MV.MBLYT.--.BHN
# MV.MBGH.--.PH1 -> MV.MBGH.--.PH1
# .MBGE.J.SBZ -> MV.MBGE.J.BHZ
# MV.MBGB.--.BHH -> MV.MBGB.--.BHH
# .MBRY.J.S A -> MV.MBRY.J.SHA
# MV.MBLG.--.BHE -> MV.MBLG.--.BHE
# .MBGH.Z.BH -> MV.MBGH.Z.BHZ
# MV.MBRY.--.BHH -> MV.MBRY.--.BHH
# .MBLG..SH -> MV.MBLG..SH
# .MBRY.J.S Z -> MV.MBRY.J.SHZ
# .MBGB..BH -> MV.MBGB..BH
# MV.MBFR.--.BHZ -> MV.MBFR.--.BHZ
# .MBLG..AP -> MV.MBLG..BDF
# .MBBY.E.BH -> MV.MBBY.E.BHE
# .MBLG..APS -> MV.MBLG..BDF
# .MBLY..BH -> MV.MBLY..BH
# MV.MBHA.--.BHH -> MV.MBHA.--.BHH
# .MBLG.J.A N -> MV.MBLG.J.SHN
# .MBLY.R.P4 -> MV.MBLY.R.PHR
# .MBLY.R.P1 -> MV.MBLY.R.PHR
# .MBBY.Z.SH -> MV.MBBY.Z.SHZ
# .MBSS.J.S Z -> MV.MBSS.J.SHZ
# .MBBE.J.SBN -> MV.MBBE.J.BHN
# MV.MBLY.--.PH1 -> MV.MBLY.--.PH1
# .MBMH.E.SH -> MV.MBMH.E.SHE
# MV.MBGH.--.BHN -> MV.MBGH.--.BHN
# MV.MBWH.--.SHZ -> MV.MBWH.--.SHZ
# .MBGH.J.SBE -> MV.MBGH.J.BHE
# MV.MBBY.--.BHZ -> MV.MBBY.--.BHZ
# .MBGB..BHN -> MV.MBGB..BHN
# MV.MBGH.--.BHZ -> MV.MBGH.--.BHZ
# .MBRV..SHZ -> MV.MBRV..SHZ
# .MBWH..SH -> MV.MBWH..SH
# .MBLY.3.PR -> MV.MBLY.3.PH3
# .MBBE.I.SBZ -> MV.MBBE.I.BHZ
# .MBMH.J.S N -> MV.MBMH.J.SHN
# .MBRV.Z.SH -> MV.MBRV.Z.SHZ
# MV.MBFL.--.SHH -> MV.MBFL.--.SHH
# MV.MBGB.--.BHE -> MV.MBGB.--.BHE
# .MBBE.J.SBE -> MV.MBBE.J.BHE
# .MBLY..PR1 -> MV.MBLY..PH1
# MV.MBGH.--.SHN -> MV.MBGH.--.SHN
# .MBGH.E.BH -> MV.MBGH.E.BHE
# MV.MBBY.--.BHE -> MV.MBBY.--.BHE
# MV.MBWH.--.SHA -> MV.MBWH.--.SHA
# MV.MBMH.--.SHZ -> MV.MBMH.--.SHZ
# MV.MBLG.--.SHN -> MV.MBLG.--.SHN
# MV.MBFL.--.BHH -> MV.MBFL.--.BHH
# MV.MBRY.--.BHE -> MV.MBRY.--.BHE
# .MBLG.Z.SH -> MV.MBLG.Z.SHZ
# .MBGH.J.SBN -> MV.MBGH.J.BHN
# .MBLG.J.S A -> MV.MBLG.J.SHA
# .MBSS.Z.SH -> MV.MBSS.Z.SHZ
# MV.MBSS.--.SHZ -> MV.MBSS.--.SHZ
# .MBLY.E.BH -> MV.MBLY.E.BHE
# MV.MBBE.--.BHE -> MV.MBBE.--.BHE
# .MBLY..PR2 -> MV.MBLY..PH2
# .MBUN.J.S Z -> MV.MBUN.J.SHZ
# .MBMH.N.SH -> MV.MBMH.N.SHN
# .MBFR..BHE -> MV.MBFR..BHE
# .MBWH.Z.SH -> MV.MBWH.Z.SHZ
# .MBBY..BHN -> MV.MBBY..BHN
# .MBRY..BHN -> MV.MBRY..BHN
# .MBGB..BHE -> MV.MBGB..BHE
# .MBLY..BHN -> MV.MBLY..BHN
# MV.MBGH.--.BHH -> MV.MBGH.--.BHH
# .MBRY.J.SBE -> MV.MBRY.J.BHE
# .MBRY.E.BH -> MV.MBRY.E.BHE
# MV.MBLY.--.PH3 -> MV.MBLY.--.PH3
# .MBLG.Z.BH -> MV.MBLG.Z.BHZ
# .MBGB..BHZ -> MV.MBGB..BHZ
# MV.MBLY.--.PH2 -> MV.MBLY.--.PH2
# .MBHA..BHZ -> MV.MBHA..BHZ
# .MBLY.4.PR -> MV.MBLY.4.PH4
# MV.MBFR.--.BHE -> MV.MBFR.--.BHE
# MV.MBRY.--.SHZ -> MV.MBRY.--.SHZ
# .MBLYT.Z.BH -> MV.MBLYT.Z.BHZ
# MV.MBLYT.--.BHZ -> MV.MBLYT.--.BHZ
# .MBWH.J.S Z -> MV.MBWH.J.SHZ
# .MBLY..PR5 -> MV.MBLY..PH5
# .MBGH..BHZ -> MV.MBGH..BHZ
# .MBRY.Z.BH -> MV.MBRY.Z.BHZ
# MV.MBWH.--.BHZ -> MV.MBWH.--.BHZ
# .MBRY.J.SBN -> MV.MBRY.J.BHN
# .MBLG.E.PRS -> MV.MBLG.E.BDF
# .MBHA.Z.BH -> MV.MBHA.Z.BHZ
# .MBGE.J.SBN -> MV.MBGE.J.BHN
# .MBFR.N.BH -> MV.MBFR.N.BHN
# .MBLY.Z.BH -> MV.MBLY.Z.BHZ
# .MBLY..PR3 -> MV.MBLY..PH3
# MV.MBGE.--.BHN -> MV.MBGE.--.BHN
# MV.MBBE.--.BHN -> MV.MBBE.--.BHN
# .MBGH..BHN -> MV.MBGH..BHN
# MV.MBLY.--.PH5 -> MV.MBLY.--.PH5
# .MBRY..BHZ -> MV.MBRY..BHZ
# .MBLG.N.BH -> MV.MBLG.N.BHN
# .MBLY.2.PR -> MV.MBLY.2.PH2
# MV.MBGE.--.BHE -> MV.MBGE.--.BHE
# .MBLG..SHZ -> MV.MBLG..SHZ
# MV.MBUN.--.SHZ -> MV.MBUN.--.SHZ
# .MBLY.R.P2 -> MV.MBLY.R.PHR
# MV.MBWH.--.BHN -> MV.MBWH.--.BHN
# .MBFL.Z.SH -> MV.MBFL.Z.SHZ
# MV.MBLG.--.BDF -> MV.MBLG.--.BHF
# MV.MBMH.--.SHN -> MV.MBMH.--.SHN
# .MBHA.E.BH -> MV.MBHA.E.BHE
# .MBBE.I.SBE -> MV.MBBE.I.BHE
# .MBLY..BHE -> MV.MBLY..BHE
# .MBMH.J.S E -> MV.MBMH.J.SHE
# MV.MBWH.--.BHE -> MV.MBWH.--.BHE
# .MBGA.J.SBE -> MV.MBGA.J.BHE
# MV.MBGB.--.BHN -> MV.MBGB.--.BHN
# .MBGH..BHE -> MV.MBGH..BHE
# .MBHA..BHN -> MV.MBHA..BHN
# .MBHA..BHE -> MV.MBHA..BHE
# MV.MBBY.--.BHH -> MV.MBBY.--.BHH
# .MBRY.N.BH -> MV.MBRY.N.BHN
# MV.MBHA.--.BHN -> MV.MBHA.--.BHN
# .MBGH.J.SBZ -> MV.MBGH.J.BHZ
# .MBBY.J.SBN -> MV.MBBY.J.BHN
# .MBFR..BHZ -> MV.MBFR..BHZ
# .MBGA.J.SBN -> MV.MBGA.J.BHN
# MV.MBFR.--.BHH -> MV.MBFR.--.BHH
# MV.MBFL.--.BHZ -> MV.MBFL.--.BHZ
# MV.MBRY.--.BHZ -> MV.MBRY.--.BHZ
# .MBRY.J.SBZ -> MV.MBRY.J.BHZ
# .MBBE.I.SBN -> MV.MBBE.I.BHN
# .MBWH..BHZ -> MV.MBWH..BHZ
# MV.MBGB.--.BHZ -> MV.MBGB.--.BHZ
# .MBLY.5.PR -> MV.MBLY.5.PH5
# MV.MB??.--.SHZ -> MV.MB??.--.SHZ
# MV.MBLG.--.SHZ -> MV.MBLG.--.SHZ
# MV.MBWH.--.BHH -> MV.MBWH.--.BHH
# MV.MBBY.--.BHN -> MV.MBBY.--.BHN
# .MBMH.J.S Z -> MV.MBMH.J.SHZ
# .MBWH.J.A N -> MV.MBWH.J.SHN
# MV.MBRV.--.SHH -> MV.MBRV.--.SHH
# MV.MBLYT.--.BHE -> MV.MBLYT.--.BHE
# .MBLYT.E.BH -> MV.MBLYT.E.BHE
# MV.MBRY.--.BHN -> MV.MBRY.--.BHN
# MV.MBLY.--.BHH -> MV.MBLY.--.BHH
# .MBGA.J.SBZ -> MV.MBGA.J.BHZ
# MV.MBGE.--.SHZ -> MV.MBGE.--.SHZ
# .MBBY.J.SBE -> MV.MBBY.J.BHE
# .MBLY.R.P3 -> MV.MBLY.R.PHR
# .MBWH..SHZ -> MV.MBWH..SHZ
# .MBWH.Z.BH -> MV.MBWH.Z.BHZ
# MV.MBFR.--.BHN -> MV.MBFR.--.BHN
# MV.MBGA.--.BHZ -> MV.MBGA.--.BHZ
# MV.MBHA.--.BHZ -> MV.MBHA.--.BHZ
# MV.MBGH.--.SHE -> MV.MBGH.--.SHE
# MV.MBFL.--.SHZ -> MV.MBFL.--.SHZ
# MV.MBHA.--.BHE -> MV.MBHA.--.BHE
# MV.MBGH.--.BHE -> MV.MBGH.--.BHE
# MV.MBLY.--.BHE -> MV.MBLY.--.BHE
# .MBSS..SH -> MV.MBSS..SH
# MV.MBLG.--.BHZ -> MV.MBLG.--.BHZ
# .MBRY..BHE -> MV.MBRY..BHE
# MV.MBBY.--.SHZ -> MV.MBBY.--.SHZ
# .MBGH..BH -> MV.MBGH..BH
# .MBLY.N.BH -> MV.MBLY.N.BHN
# MV.MBLY.--.SHZ -> MV.MBLY.--.SHZ
# .MBBY.N.BH -> MV.MBBY.N.BHN
# .MBGB.Z.BH -> MV.MBGB.Z.BHZ
# MV.MBGA.--.BHN -> MV.MBGA.--.BHN
# MV.MBLY.--.BHN -> MV.MBLY.--.BHN
# MV.MBRV.--.SHZ -> MV.MBRV.--.SHZ
# MV.MBRY.--.SHN -> MV.MBRY.--.SHN
# MV.MBLY.--.PH6 -> MV.MBLY.--.PH6
# .MBFL..SHZ -> MV.MBFL..SHZ
# MV.MBGA.--.BHE -> MV.MBGA.--.BHE
# .MBMH.Z.SH -> MV.MBMH.Z.SHZ
# MV.MBLY.--.PH4 -> MV.MBLY.--.PH4
# .MBBY.J.SBZ -> MV.MBBY.J.BHZ
# .MBBE.J.SBZ -> MV.MBBE.J.BHZ
# MV.MBGH.--.SHZ -> MV.MBGH.--.SHZ
# .MBFR.Z.BH -> MV.MBFR.Z.BHZ
# .MBGB.N.BH -> MV.MBGB.N.BHN
# MV.MBGH.--.PHR -> MV.MBGH.--.PHR
# .MBHA.N.BH -> MV.MBHA.N.BHN
# .MBLG..BHZ -> MV.MBLG..BHZ
# .MBGH.2.PR -> MV.MBGH.2.PH2
# .MBLG.S.AP -> MV.MBLG.S.BDF
# .MBBY.Z.BH -> MV.MBBY.Z.BHZ
# .MBGH.N.BH -> MV.MBGH.N.BHN
# MV.MBBE.--.BHZ -> MV.MBBE.--.BHZ
# .MBLY.Z.SH -> MV.MBLY.Z.SHZ
# MV.MBMH.--.SHE -> MV.MBMH.--.SHE
# .MBSS..SHZ -> MV.MBSS..SHZ
# MV.MBGE.--.BHZ -> MV.MBGE.--.BHZ
# MV.MBGH.--.PH2 -> MV.MBGH.--.PH2
# .MBWH..BHE -> MV.MBWH..BHE
# .MBFR..BHN -> MV.MBFR..BHN
# .MBLG.E.BH -> MV.MBLG.E.BHE
# .MBGB.J.SBE -> MV.MBGB.J.BHE
# .MBLY.6.PR -> MV.MBLY.6.PH6
# .MBLG.J.S Z -> MV.MBLG.J.SHZ
# MV.MBLG.--.DHM -> MV.MBLG.--.DHM
# .MBWH..BHN -> MV.MBWH..BHN
# .MBRY.J.A N -> MV.MBRY.J.SHN
# .MBLY..BHZ -> MV.MBLY..BHZ
# MV.MBWH.--.SHN -> MV.MBWH.--.SHN
# .MBLYT.N.BH -> MV.MBLYT.N.BHN
# .MBLY.R.P6 -> MV.MBLY.R.PHR
# .MBRV..SH -> MV.MBRV..SH
# .MBWH.E.BH -> MV.MBWH.E.BHE
# MV.MBLG.--.BHN -> MV.MBLG.--.BHN
# .MBGB.J.SBZ -> MV.MBGB.J.BHZ
